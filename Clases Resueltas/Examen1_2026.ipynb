# %% [markdown]
# # Examen 1 - Comprensión de modelos de regresión y KNN
# Maria Fernanda Gómez Flores
# ## Instrucciones
#
# **Puntaje total:** 100 puntos

# %% [markdown]
# ## Sección 1: Regresión lineal e interpretación de modelos (25 puntos)

# %% [markdown]
# ### 1. Regresión simple vs. regresión múltiple (8 puntos)
#
# Una inmobiliaria quiere predecir el precio de una casa.
#
# 1. ¿Cuál es la diferencia entre una regresión lineal simple y una regresión lineal múltiple?
# la diferencia entre una regresión lineal simple y una regresión lineal múltiple es que
# en una regresión lineal simple se utiliza una sola variable independiente (X) para predecir el valor de Y y en la múltiple se usan varias variables independientes para predecir a Y
#
# 2. Da un ejemplo concreto de cada una usando variables de casas.
# un ejemplo de regresión lineal simple seria usar el tamaño de la casa(x) para predecir el precio de la casa (y)
# y para la regresión lineal multiple seria usar el tamaño de la casa(x1), el número de habitaciones(x2) y la ubicación(x3) para predecir el precio de la casa (y)
#
# 3. ¿Por qué agregar más variables no siempre mejora un modelo de manera real?
# agregar mas variables puede no mejorar el modelo siempre porque puede haber un sobreajuste que se llama overfitting
# esto pasa cuando el modelo se ajusta demasiado a los datos de entrenamiento y no generaliza bien a nuevos datos

# %% [markdown]
# ### 2. Interpretación de coeficientes (9 puntos)
#
# Supongamos que se ajusta el siguiente modelo:
#
# $$
# \widehat{precio} = 45 + 2.1(tamaño\_m2) + 18(habitaciones) - 0.7(edad)
# $$
#
# El precio está medido en miles de pesos.
#
# 1. Interpreta el intercepto.
# es cuando el modelo predice un precio de 45 mil pesos para una vivienda de 0 m2 , 0 habitaciones y 0 años de edad
#
# 2. Interpreta el coeficiente de `tamaño_m2`.
# cuando se mantiene constantes habitación y edad si el tamaño aumenta en 1 m2 el precio predicho aumenta en 2,100 de pesos
#
# 3. Interpreta el coeficiente de `habitaciones`.
# cuando se mantiene constantes tamaño y edad si habitaciones aumenta en 1  el precio predicho aumenta en 18000  de pesos
# 4. Interpreta el coeficiente de `edad`.
# cuando se mantiene constantes habitación y tamaño si año aumenta en 1  el precio predicho disminuye en .7 miles de pesos
# 5. ¿Por qué la frase "una recámara siempre aumenta el precio en 18 mil pesos" puede ser una interpretación incompleta?
# porque no es siempre ya que las demas variables tmb se deben de mantenber constantes y la frase no dice eso

# %% [markdown]
# ### 3. Calidad del modelo y residuales (8 puntos)
#
# Dos modelos predicen precios de casas:
#
# - Modelo A: errores pequeños para casas de precio medio, pero errores muy grandes para casas caras.
# - Modelo B: errores moderados y parecidos en todo el rango de precios.
#
# 1. ¿Cuál modelo preferirías si el objetivo es tener predicciones estables? Justifica.
# porque aunque sus errores no sean tan pequeños
#  son más parecidos en todo el rango de precios y eso es mas estable
#
# 2. ¿Qué te diría una gráfica de residuales contra predicciones?
# me ayudaría a ver cómo se comportan los errores del modelo ya que veria bueno lo ideal sería que los residuales estuvieran alrededor de 0 y sin un patron
#
# 3. ¿Qué patrón en los residuales te haría sospechar que el modelo se equivoca de manera sistemática?
# si los residuales forman algún patrón o si todos los errores son negativos o positivos

# %% [markdown]
# ## Sección 2: R2 y evaluación del modelo (20 puntos)
#
# ### 4. Intuición de R2 (8 puntos)
#
# Explica intuitivamente qué mide el R2. Tu respuesta debe incluir:
#
# El R2 dice que tanto mejor esta explicando el modelo los datos comparado con simplemente predecir siempre el promedio si el R2 esta cerca de 0 quiere decir que el modelo casi no predice o mejora bien la predicion y si el R2 es alto quiere decir que el modelo si esta explicando buena parte de la variacion de los datos y deja menos error sin explicar por eso nos sirve para comparar si un modelo de verdad esta aportando informacion o si practicamente seria igual usar el promedio.
#
# 1. ¿Qué significa comparar el modelo contra predecir siempre el promedio?
# 2. ¿Qué significa un R2 cercano a 0?
# 3. ¿Qué significa un R2 alto?
# 4. ¿Por qué el R2 nos ayuda a comparar si un modelo está explicando mejor los datos que una predicción muy simple?
#
# ### 5. Train/test y generalización (6 puntos)
#
# Un estudiante entrena un modelo y obtiene:
#
# - R2 de entrenamiento: 0.96
# - R2 de prueba: 0.58
#
# 1. ¿Qué problema parece haber?
# Parece que hay overfitting
# 2. ¿Por qué ocurre?
# porque el R2 en el enrenamiento se ajusto demasiado en los datos de entrenamiento y puede que memorice esos datos en vez de poder predecirlo
# 3. ¿Qué cambios intentarías para mejorar la generalización?
# usar Ridge y pudiera hacer validación cruzada
#
# ### 6. Comparación de modelos usando R2 (6 puntos)
#
# Supongamos que entrenas tres modelos para predecir precios de casas:
#
# - Modelo A: R2 train = 0.62, R2 test = 0.60
# - Modelo B: R2 train = 0.91, R2 test = 0.55
# - Modelo C: R2 train = 0.78, R2 test = 0.74
#
# 1. ¿Cuál modelo escogerías y por qué?
# escogeria el modelo C porque tiene un buen R2 en train y test y justo se ve que no solo lo memorizo si no si aprendio porque no hay tanta diferenciua en los errores
# 2. ¿Cuál modelo parece estar memorizando demasiado el entrenamiento?
# el B
# 3. ¿Cuál modelo parece demasiado simple?
# el A
# 4. ¿Por qué conviene mirar el R2 de entrenamiento y el R2 de prueba al mismo tiempo?
# ya qu justo podemos ver si no hay un overfitting y solo esta memorizando el entrenamiento pero no es capaz de predecir

# %% [markdown]
# ## Sección 3: Descenso en gradiente y regresión polinomial (20 puntos)
#
# ### 7. Función de costo y descenso en gradiente (10 puntos)
#
# Explica cómo aprende una regresión lineal usando descenso en gradiente. Tu explicación debe incluir:
#
# 1. ¿Qué representa la función de costo?
# dice que tan mal esta haciendo el modelo osea compara el dato real con lo que se predijo entre mas pequeño sea mejor
# 2. ¿Qué significa la pendiente o gradiente de la función de costo?
# la pendiente dice hacua que lado esta o subiendo o bajando la funcion de costo , dice donde mover las betas para q se pueda reducir el error
# 3. ¿Cómo se actualizan los coeficientes?
# se actualizan restando el gradiente poco a poco multiplicando por el learning rate hasta que el error ya es mucho mucho menor
# 4. ¿Qué papel juega el learning rate?
# es como el tamaño del paso que da el modelo cada vez que cambia las betas
# 5. ¿Qué podría pasar si el learning rate es demasiado grande o demasiado pequeño?
# Si el learning rate es muy grande el modelo puede dar pasos demasiado grandes y nunca llegar bien al punto donde el error es menor y si es muy pequeño si puede ir mejorando pero va a avanzar super lento y le va a tomar mucho mas llegar a una buena solucion.
#
#
# ### 8. Regresión polinomial (5 puntos)
#
# Explica qué hace una regresión polinomial. En particular:
#
# 1. ¿Por qué sigue siendo una regresión lineal en los parámetros aunque use potencias de X?
# porque las betas siguen normales con la forma lineal
# 2. ¿Qué cambia cuando aumentamos el grado del polinomio?
# se vuelve mas flexible y hacer las curvas mas conflejas
# 3. ¿Qué riesgo aparece si usamos un grado muy alto?
# aumenta el riesgo de que el modelo siga demasiado el ruido de los datos y puede haber overfitting ya que el modelo se ajusta mucho a los datos de entrenamiento
#
# ### 9. Overfitting y underfitting (5 puntos)
#
# Compara estos dos modelos:
#
# - Modelo A: polinomio grado 1, R2 train = 0.45, R2 test = 0.43
# - Modelo B: polinomio grado 9, R2 train = 0.99, R2 test = 0.51
#
# 1. ¿Cuál modelo parece tener underfitting?
# El A
# 2. ¿Cuál modelo parece tener overfitting?
# El B
# 3. ¿Qué tipo de modelo intentarías después y por qué?
# pues uno en medio osea no tan simple como el 1 pero tampoco tan alto como el 9 quizas un 5 que sea suficiente para captar mejor la forma de los datos pero que no se pasa y se termine memorizando el train

# %% [markdown]
# ## Sección 4: Ridge, escalamiento y estabilidad (15 puntos)
#
# ### 10. Ridge regression (7 puntos)
#
# Ridge es una regresion que  castiga cuando las betas se hacen demasiado grandes entonces hace que los coeficientes se vuelvan mas pequeños y como menos exagerados y esto ayuda cuando hay overfitting porque el modelo deja de ajustarse tanto a los datos de train y puede generalizar mejor con datos nuevos, Ridge no elimina las variables directamente porque normalmente no hace que las betas lleguen exactamente a 0 solo las va reduciendo entonces las variables siguen estando en el modelo pero con mucho menos peso
#
# 1. ¿Qué penaliza Ridge?
# 2. ¿Cómo cambia el comportamiento de los coeficientes?
# 3. ¿Por qué puede ayudar cuando hay overfitting?
# 4. ¿Por qué Ridge no elimina variables de manera directa?
#
# ### 11. Alpha y trade-off (4 puntos)
#
# En Ridge, compara estos tres casos:
#
# - alpha = 0
# - alpha pequeño
# - alpha muy grande.
#
# en alpha 0 basicamente no hay ninguna penalización osea que ridge se comporta como una regresion normalita los coeficiente son mas grandes con un sesgo menor pero la varianza tmb es mayor y se ajuta demasiado al train, con el alpha pequeño los coeficientes se reducen un poco sube el sesgo y baja la varianza esto ayuda a que generalice mejor y con alpha muy grande los coeficientes se hacen super pequeños aumenta el sesgo y baja la varianza pero se pudiera perder la capacidad de ajuste y puede ser un underfitting
#
# Explica qué ocurre con los coeficientes, el sesgo, la varianza y la capacidad de ajuste.
#
# ### 12. StandardScaler (4 puntos)
#
# Explica por qué es importante escalar variables antes de usar Ridge o modelos basados en distancia, como KNN. Da un ejemplo de qué podría salir mal si no se escala.
#
# Es importante escalar porque las variables pueden estar en escalas muy diferentes y eso afecta el tamaño de los coeficientes
# usando Ridge importa porque penaliza coeficientes grandes y en KNN importa porque usa distancias  por ejemplo si tienes metros cuadrados con valores muy grandes y habitaciones con valores de 1 al 7 sin escalar una variable puede terminar pesando mas solo por el tamaño de sus numeros se suele inclinar a los valores mas grandes
#
# ---

# %% [markdown]
# ## Sección 5: KNN y validación (20 puntos)
#
# ### 13. K-nearest neighbors (10 puntos)
#
# Explica cómo predice KNN. Tu respuesta debe incluir:
#
# 1. ¿Qué significa "vecinos más cercanos"?
# pues son los datos o observaciones que mas se parecen al dato nuevo
#
# 2. ¿Cómo se usa la distancia entre observaciones?
# calculando la distancia entre el dato nuevo y los de entrenamiento y se queda con los K que tengan menor distanciaa.
# 3. ¿Cómo se calcula una predicción en regresión?
# con los valores de y de los vecinos y hace el promedio para poderlos predecir
# 4. ¿Cómo se calcula una predicción en clasificación?
#
# 5. ¿Por qué KNN depende tanto de la escala de las variables?
# porque usa distancias , si una variale tiene numeros mas grande puede terminar dominando la distancia solo por la escala y no va a poder encontrar bien a los que aparecen como vecinos
# ### 14. Elegir k y usar cross validation (10 puntos)
#
# Compara estos escenarios:
#
#
#
# - k = 1
# - k intermedio
# - k muy grande
#
# 1. ¿Cuál tiende a sobreajustar?
# el de K=1 porque depende literalmente de un solo vecino y esta muy pegado a los datos que tiene el entrenamiento
# 2. ¿Cuál puede subajustar?
# el k muy grande  usa muchos vecinos y suaviza la predicción
# 3. ¿Cómo usarías cross validation para elegir k?
# te ayuda a ver cual tiene el mejor resultado promedio
# 4. ¿Cómo usarías el R2 para comparar distintos valores de k en un problema de regresión?
# calculando R2 en cada K y busco el que este alto en validacion y en el test
# 5. ¿Por qué no escogerías automáticamente el k que mejor funciona en una sola partición de datos?
# porque chance pueda que solo le favorecio en esa división y con cross validation se prueba varias veces en distintas partes y eso te ayuda a ver bien para que funcione en general
