# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Import housing
df = pd.read_csv('housing.csv')
df = df[['median_income', 'median_house_value', 'latitude']]

# %%
# Modelo bueno, median income

# Predicciones

# %%
model1.predict(X1).ravel()
# Out:
# array([393027.73007889, 392033.03646789, 348400.25790111, ...,
#        116135.12034649, 123123.05193305, 144914.36490692])

# %%
# Modelo malo, latitud (no debe de ser bueno)


# Predicciones

# %%
# Junta todo

# %%
# Volatilidad target

# %%
# Volatilid residuos con modelo bueno

# %%
# Volatilid residuos con modelo malo

# %% [markdown]
# ## A esto le llammmos R2 y será la métrica que usaremos todo el curso
#
# $$R_2 = \frac{Var(y) - Var(residuales)}{Var(y)}$$
