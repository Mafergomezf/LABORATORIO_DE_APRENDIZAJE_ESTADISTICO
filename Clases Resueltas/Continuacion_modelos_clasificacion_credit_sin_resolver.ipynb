# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ###  Cargamos el dataset

# %%
from sklearn.datasets import fetch_openml
X, y = fetch_openml("credit-g", as_frame=True, parser="auto", return_X_y=True)

# %%
# Dummies y transforma la y
X=pd.get_dummies(X)

# %%
# Que tan balanceado está
y=y=='good'

# %%
np.mean(y)
# Out:
# np.float64(0.7)

# %% [markdown]
# ### Crea un modelo

# %%
# Crea rápidamente una regresión logistica
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=0)

model=linear_model.LogisticRegression()
model.fit(X_train,y_train)
probabilidades=model.predict_proba(X_test)[:,1]
probabilidades
# Out:
# array([0.33733831, 0.93155047, 0.97449548, 0.35000492, 0.63467373,
#        0.84225755, 0.87898266, 0.89564969, 0.94559113, 0.32382871,
#        0.06092773, 0.34583833, 0.9772305 , 0.72476898, 0.26716374,
#        0.93806741, 0.7282913 , 0.90614557, 0.4238804 , 0.89450663,
#        0.28196201, 0.21705846, 0.57082737, 0.57437562, 0.96246557,
#        0.21055461, 0.82560171, 0.79133776, 0.9898331 , 0.64643936,
#        0.63145272, 0.95907668, 0.90413993, 0.84630061, 0.91392681,
#        0.53120018, 0.91962233, 0.9268024 , 0.47692923, 0.8175281 ,
#        0.54777339, 0.59629379, 0.90718455, 0.88825774, 0.84998322,
#        0.25226082, 0.58112647, 0.25479737, 0.68014807, 0.30609006,
#        0.93784996, 0.31685021, 0.34542524, 0.5133418 , 0.67743582,
#        0.88616605, 0.12700411, 0.96272221, 0.99038913, 0.57701275,
#        0.32041598, 0.9480302 , 0.36758987, 0.83349807, 0.80534882,
#        0.97411018, 0.95623728, 0.67716628, 0.24999998, 0.88536449,
#        0.94335393, 0.86658289, 0.30096302, 0.45851992, 0.37354981,
#        0.80611481, 0.91324748, 0.91656876, 0.66170107, 0.96573309,
#        0.66454253, 0.45244295, 0.94645517, 0.66505505, 0.90325781,
#        0.7811401 , 0.6441641 , 0.46985679, 0.93929078, 0.41268423,
#        0.90864559, 0.42275145, 0.73024975, 0.88855541, 0.88570471,
#        0.70780285, 0.76361173, 0.73718228, 0.38021739, 0.62442398,
#        0.65996545, 0.93704594, 0.94270348, 0.93735323, 0.95184522,
#        0.93506144, 0.39095306, 0.19325013, 0.17513526, 0.96603213,
#        0.68732351, 0.0599185 , 0.14214305, 0.96799664, 0.62192982,
#        0.92540459, 0.23316394, 0.93717924, 0.82651193, 0.67462085,
#        0.8274025 , 0.91748914, 0.83285772, 0.25463012, 0.76770464,
#        0.89153174, 0.93518044, 0.98792591, 0.990852  , 0.83245734,
#        0.80227783, 0.67597011, 0.27651476, 0.7543996 , 0.86565184,
#        0.48925251, 0.73310566, 0.98757347, 0.60062283, 0.17213535,
#        0.56091409, 0.3129943 , 0.80125404, 0.93633757, 0.94235114,
#        0.19265369, 0.89526328, 0.59733345, 0.8573116 , 0.2647584 ,
#        0.78405688, 0.98136419, 0.89651354, 0.95147585, 0.91267587,
#        0.88413948, 0.76435661, 0.09595439, 0.92429405, 0.85460235,
#        0.67826462, 0.58533775, 0.78258848, 0.85303022, 0.14272151,
#        0.53764591, 0.5766868 , 0.93371189, 0.2410188 , 0.04301584,
#        0.96859035, 0.8733134 , 0.94366819, 0.51733723, 0.91463707,
#        0.9881022 , 0.85688958, 0.51412831, 0.21053187, 0.95847317,
#        0.90145614, 0.14407313, 0.77359972, 0.46805236, 0.44722408,
#        0.97374694, 0.91683958, 0.91499266, 0.58765591, 0.17346011,
#        0.97283433, 0.12329852, 0.73448414, 0.34238628, 0.77972218,
#        0.42120318, 0.58264319, 0.88913487, 0.87877661, 0.811315  ,
#        0.72296755, 0.84002166, 0.83640188, 0.94620286, 0.50556778,
#        0.15571679, 0.65902065, 0.89768362, 0.85148301, 0.79445922,
#        0.9395116 , 0.90492303, 0.95208126, 0.8859444 , 0.22521531,
#        0.9558664 , 0.99238976, 0.62425985, 0.91979517, 0.74094206,
#        0.8650079 , 0.93844174, 0.5478204 , 0.93327719, 0.95607888,
#        0.79919054, 0.97333712, 0.96086409, 0.25897523, 0.36292445,
#        0.85878771, 0.88053848, 0.9712301 , 0.44867805, 0.88263133,
#        0.98848933, 0.94180317, 0.97593481, 0.94182065, 0.59108138,
#        0.72327042, 0.98422449, 0.51001024, 0.60656536, 0.94020496,
#        0.33804501, 0.88692095, 0.57469473, 0.78329722, 0.71591866,
#        0.22542173, 0.35640861, 0.84586646, 0.88776772, 0.83176628,
#        0.92947599, 0.55387995, 0.67825732, 0.43227173, 0.58831472,
#        0.91659474, 0.87286446, 0.70239154, 0.93612053, 0.79827186,
#        0.96926476, 0.67069845, 0.05101839, 0.1054668 , 0.63534652,
#        0.76470809, 0.16033582, 0.5545925 , 0.25459268, 0.4508362 ,
#        0.81037715, 0.92152411, 0.97955326, 0.54115702, 0.65274207,
#        0.53416567, 0.42352627, 0.95007397, 0.91268994, 0.9835207 ,
#        0.96334455, 0.51074886, 0.95914457, 0.56645256, 0.267997  ,
#        0.42203845, 0.70514141, 0.97260928, 0.66298444, 0.91859437,
#        0.96054544, 0.12228414, 0.86157484, 0.68474016, 0.98414803,
#        0.94476387, 0.70927087, 0.54216059, 0.51715704, 0.08692903,
#        0.92241045, 0.47916457, 0.28489885, 0.44288758, 0.94537349,
#        0.54843244, 0.84821043, 0.62568971, 0.79274267, 0.3527907 ,
#        0.93894591, 0.93534042, 0.94642655, 0.93787856, 0.17868384])

# %% [markdown]
# ### Concepto odds
#
# Mi equipo gana 1 a 4

# %% [markdown]
# Probabilidad de ganar

# %% [markdown]
# Probabilidad perder

# %% [markdown]
# Mi equipo gana 5 a 3

# %% [markdown]
# Probabilidad que equipo gane

# %% [markdown]
# Probabilidd de perder

# %% [markdown]
# ¿Qué pasa si divido la probabilidad de ganar entre la probabiliad de perder?

# %% [markdown]
# $$odds = \frac{p}{1-p}$$
#
#
# $$log(\frac{p}{1-p}) = \Theta ^T X$$
#
#
# Aplicamos la exponencial en ambos lados:
#
# $$
# e^{\Theta ^T X} = \frac{p}{1 - p}
# $$
#
# Despejamos \( p \):
#
# $$
# p = \frac{e^{\Theta ^T X}}{1 + e^{\Theta ^T X}}
# $$
#
# Simplificando
#
# $$
# p= \frac{1}{1 + e^{-\Theta ^T X}}
# $$
#
# Calcula los odds de las predicciones

# %%
# Predicciones

# Odds

# %% [markdown]
# Los odds pueden llegar a ser muy volatiles

# %%
log_odds = np.log(odds)

# %% [markdown]
# $$log(odds) = log(\frac{p}{1-p})$$
#
# Pero el log odds no es tan disperso

# %%
# Calcula y grafica los log odds

# %% [markdown]
# ### ¿Y esto que?
#
# Si tomamos los coeficientes de una regresión logistica como si gura una regresión lineal, obtenemos un numero extraño
#
# $$z = \Theta ^T X $$

# %%
# Calcula Z 
# z = X_test @ model.coef_.T + model.intercept_

# %% [markdown]
# Resulta ser que z es lo mismo que log odds

# %% [markdown]
# ### Esto es importante porque de aquí sale sigmoide

# %% [markdown]
# $$log(\frac{p}{1-p}) = \Theta ^T X$$
#
#
# Aplicamos la exponencial en ambos lados:
#
# $$
# e^{\Theta ^T X} = \frac{p}{1 - p}
# $$
#
# Despejamos \( p \):
#
# $$
# p = \frac{e^{\Theta ^T X}}{1 + e^{\Theta ^T X}}
# $$
#
# Simplificando
#
# $$
# p= \frac{1}{1 + e^{-\Theta ^T X}}
# $$

# %% [markdown]
# Comprobando

# %% [markdown]
# ### _Comprobamos que Sklearn opera conforme a la teoría_

# %% [markdown]
# ### Comparando diferentes tipos de regresiones
#
# #### Modelo lineal

# %% [markdown]
# #### Checando los coeficientes

# %% [markdown]
# ## ¿Qué significa esto?

# %% [markdown]
# ### Log loss
#
# $$
# \text{LogLoss} = -\frac{1}{N} \sum_{i=1}^{N} \left[ y_i \log(p_i) + (1 - y_i) \log(1 - p_i) \right]
# $$

# %% [markdown]
# ### Crea una regresión logistica

# %%
from sklearn.metrics import log_loss, accuracy_score

# %% [markdown]
# ## Polinomial

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# penalty='l2'
# scoring='neg_log_loss'

# %% [markdown]
# ## Comparación de histogramas

# %%
df_hist= pd.DataFrame({
    'y': y_test,
    'poly': grid.predict_proba(X_test)[:,1],
    'lineal': model_linear.predict_proba(X_test)[:,1]
})

# %% [markdown]
# ## Calibracion
